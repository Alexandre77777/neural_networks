# %% [markdown]
# <a href="https://colab.research.google.com/github/Alexandre77777/neural_networks/blob/main/7.%20%D0%98%D1%81%D0%BF%D0%BE%D0%BB%D1%8C%D0%B7%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D0%B5%20%D0%B0%D0%B2%D1%82%D0%BE%D1%8D%D0%BD%D0%BA%D0%BE%D0%B4%D0%B5%D1%80%D0%B0%20%D0%B4%D0%BB%D1%8F%20%D1%80%D0%B5%D1%88%D0%B5%D0%BD%D0%B8%D1%8F%20%D0%B7%D0%B0%D0%B4%D0%B0%D1%87%20%D1%81%D0%B5%D0%BC%D0%B0%D0%BD%D1%82%D0%B8%D1%87%D0%B5%D1%81%D0%BA%D0%BE%D0%B9%20%D1%81%D0%B5%D0%B3%D0%BC%D0%B5%D0%BD%D1%82%D0%B0%D1%86%D0%B8%D0%B8/%D0%A0%D0%B0%D0%B1%D0%BE%D1%82%D0%B0_%E2%84%967_%D0%98%D1%81%D0%BF%D0%BE%D0%BB%D1%8C%D0%B7%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D0%B5_%D0%B0%D0%B2%D1%82%D0%BE%D1%8D%D0%BD%D0%BA%D0%BE%D0%B4%D0%B5%D1%80%D0%B0_%D0%B4%D0%BB%D1%8F_%D1%80%D0%B5%D1%88%D0%B5%D0%BD%D0%B8%D1%8F_%D0%B7%D0%B0%D0%B4%D0%B0%D1%87_%D1%81%D0%B5%D0%BC%D0%B0%D0%BD%D1%82%D0%B8%D1%87%D0%B5%D1%81%D0%BA%D0%BE%D0%B9_%D1%81%D0%B5%D0%B3%D0%BC%D0%B5%D0%BD%D1%82%D0%B0%D1%86%D0%B8%D0%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Практическая работа №7. Использование автоэнкодера для решения задач семантической сегментации**

# %% [markdown]
# ### Для выполнения задания необходимо скачать датасет по ссылке (снимки и маски, Version 1) . Обучить нейронную сеть предсказывать полноразмерную маску по загруженному снимку (см. теорию)

# %% [markdown]
# - ### Ссылка на датасет: https://landcover.ai.linuxpolska.com/#dataset

# %% [markdown]
# # Задание №1. Обучение готовой модели семантической сегментации для классификации спутниковых снимков

# %% [markdown]
# - Для работы с tiff-изображениями предлагается использовать библиотеку tifffile

# %%
pip install tifffile
# Out:
# Requirement already satisfied: tifffile in c:\users\sa32\anaconda3\envs\tf\lib\site-packages (2023.3.21)
# Requirement already satisfied: numpy in c:\users\sa32\anaconda3\envs\tf\lib\site-packages (from tifffile) (1.24.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import cv2
import numpy as np
import glob

import numpy as np
from matplotlib import pyplot as plt
from patchify import patchify
import tifffile as tiff
from PIL import Image
import tensorflow as tf
from tensorflow import keras
import segmentation_models as sm
from tensorflow.keras.metrics import MeanIoU
import random
# Out:
# Segmentation Models: using `keras` framework.

# %% [markdown]
# *Далее даны примеры кода, для их корректной работы пути необходимо сменить на Ваши*

# %% [markdown]
# ### 1.1. Проверка вывода растра и масок

# %%
temp_img = tiff.imread('C:\\Users\\sa32\\YandexDisk\\VIZARD\\Composit\\S1A_EW_GRDM_1SDH_20210928T011042_20210928T011146_039875_04B7B8_C842.tif')
# plt.imshow(temp_img[:,:,0])

temp_mask = tiff.imread('C:/Users/sa32/YandexDisk/VIZARD/Classification/S1A_EW_GRDM_1SDH_20210928T011042_20210928T011146_039875_04B7B8_C842.tif')
plt.imshow(temp_mask)

print(temp_img.shape)
print(temp_img.dtype)
print(temp_mask.shape)

labels, count = np.unique(temp_mask[:,:,2], return_counts=True) #Check for each channel. All chanels are identical
print("Labels are: ", labels, " and the counts are: ", count)

# %%
root_directory = r"C:/Users/sa32/YandexDisk/VIZARD/"

patch_size = 256

# %% [markdown]
# ### 1.2. Обрезка исходных растров на фрагменты (патчи) размером 256x256. Сохраните их в каталог на локальное хранилице

# %%
#Считываем изображения из подкаталога 'images'.
#Поскольку все изображения имеют разный размер, у нас есть 2 варианта: изменить размер или обрезать.
#Но некоторые изображения слишком большие, а некоторые маленькие. Изменение размера изменит размер реальных объектов.
#Поэтому мы обрезаем их до ближайшего размера, кратного 256, а затем
#разделим все изображения на участки размером 256x256x3.
img_dir=root_directory+"Composit/"
for path, subdirs, files in os.walk(img_dir):
    print(path)
    dirname = path.split(os.path.sep)[-1]
    print(dirname)
    images = os.listdir(path)
    print(images)
    for i, image_name in enumerate(images):
        if image_name.endswith(".tif"):

            image = tiff.imread(path+"/"+ image_name)

            SIZE_X = (image.shape[1]//patch_size)*patch_size
            SIZE_Y = (image.shape[0]//patch_size)*patch_size

            image = image[0:SIZE_Y, 0:SIZE_X]

            print("Now patchifying image:", path+"/"+image_name)
            patches_img = patchify(image, (256, 256, 3), step=256)

            for i in range(patches_img.shape[0]):
                for j in range(patches_img.shape[1]):

                    single_patch_img = patches_img[i,j,:,:]
                    single_patch_img = single_patch_img[0]

                    tiff.imwrite(root_directory+"256_patches/images/" + image_name +
                                 "patch_" + str(i) + str(j) + ".tif", single_patch_img, photometric='rgb')

# %% [markdown]
# ### 1.3. Обрезка исходных масок на фрагменты (патчи) размером 256x256. Сохраните их в каталог на локальное хранилице

# %%
mask_dir=root_directory+"Classification/"
for path, subdirs, files in os.walk(mask_dir):
    #print(path)
    dirname = path.split(os.path.sep)[-1]

    masks = os.listdir(path)
    for i, mask_name in enumerate(masks):
        if mask_name.endswith(".tif"):

            mask = tiff.imread(path + "/" + mask_name)


            SIZE_X = (mask.shape[1]//patch_size)*patch_size
            SIZE_Y = (mask.shape[0]//patch_size)*patch_size

           mask = mask[0:SIZE_Y, 0:SIZE_X]

            print("Now patchifying mask:", path+"/"+mask_name)
            patches_mask = patchify(mask, (256, 256, 3), step=256)

            for i in range(patches_mask.shape[0]):
                for j in range(patches_mask.shape[1]):

                    single_patch_mask = patches_mask[i,j,:,:]
                    single_patch_mask = single_patch_mask[0]
                    tiff.imwrite(root_directory+"256_patches/masks/"+
                               mask_name+"patch_"+str(i)+str(j)+".tif", single_patch_mask, photometric='minisblack')

# %% [markdown]
# ### 1.4. Проверка патчей масок и исходного растра на соответствие

# %%
# Ваш код

# %% [markdown]
# ### 1.5. Отсев неинформативных растров и соответствующих масок

# %% [markdown]
# Пропускаем изображения на которых один класс заднимает более 95% площади

# %%
# Скопируем изображения и маски с реальной информацией в новую папку.

useless=0
for img in range(len(img_list)):
    img_name=img_list[img]
    mask_name = msk_list[img]
    print("Now preparing image and masks number: ", img)

    temp_image=tiff.imread(train_img_dir+img_list[img])

    temp_mask=tiff.imread(train_mask_dir+msk_list[img])
    #temp_mask=temp_mask.astype(np.uint8)

    val, counts = np.unique(temp_mask, return_counts=True)

    if (1 - (counts[0]/counts.sum())) > 0.05:  # От 5% полезной площади
        tiff.imwrite(r'C:\Users\sa32\YandexDisk\VIZARD\256_patches\images_with_useful_info\images\\'+ img_name, temp_image, photometric='rgb')
        tiff.imwrite(r'C:\Users\sa32\YandexDisk\VIZARD\256_patches\images_with_useful_info\masks\\'+mask_name, temp_mask, photometric='rgb')

    else:
        useless +=1

print("Total useful images are: ", len(img_list)-useless)  #20,075
print("Total useless images are: ", useless) #21,571

# %% [markdown]
# ### 1.6. Формирование папок с обучающей и валидационной выборкой

# %% [markdown]
# ### Разделение данных по папкам на обучающую и проверочную выборку (после разделения снимка и маски на патчи)
#
#
# Ниже представлен Код для разделения папки на train и val.
# После создания новых папок переименуйте их и расположите в формате, приведенном ниже, для использования для семантической сегментации с помощью генераторов данных.
#
# [Документация](https://pypi.org/project/split-folders/)

# %%
# !pip install split-folders

# %% [markdown]
# ### Подсказка

# %%
# Ваш код

# %%
import splitfolders  # или import split_folders

input_folder = r'C:\Users\sa32\YandexDisk\VIZARD\256_patches\images_with_useful_info\\'
output_folder = r'C:\Users\sa32\YandexDisk\VIZARD\data_for_training_and_testing\\'

splitfolders.ratio(input_folder, output=output_folder, seed=42, ratio=(.75, .25), group_prefix=None) # default values

# %% [markdown]
# Структура конечных папок для генератора (ImageDataGenerator()):
#
# (После разделения на папки, нужно разместить вручную или написать для этого специальную функцию, например, используя модули os и/или shutil)
#
#
#
# ```
# dataset
#         train_image
#                     train
#         train_mask
#                     train
#         val_image
#                     val
#         val_mask
#                     val
# ```

# %%
# Ваш код

# %% [markdown]
# ## Этап 2. Предобработка обучающей и валидационной выборки

# %% [markdown]
# ### 2.1. Инициализация сформированной выборки

# %%
# Ваш код

# %% [markdown]
# #### Проверка

# %%
# Ваш код

# %% [markdown]
# ### 2.2. Предобработка обучающей выборки

# %% [markdown]
# Обратите внимание на формат масок в датасете. Возможно для решения этой задачи нет необходимости изменять исходные значения пикселей в маске.

# %%
# Ваш код

# %% [markdown]
# ### Нормализация исходного патча и маски

# %%
# Ваш код

# %% [markdown]
# #### Проверка

# %%
# Ваш код

# %% [markdown]
# ### 2.3. Формирование последовательной загрузки набора данных с жесткого диска для обучения модели, используя Keras.ImageDataGenerator()

# %%
# Ваш код

# %% [markdown]
# #### Проверка:

# %%
# Ваш код

# %% [markdown]
# ## Этап 3. Разработка архитектуры модели. Обучение модели

# %% [markdown]
# * Изучите техническую докуентацию по работе с модулем [Segmentation Models](https://segmentation-models.readthedocs.io/en/latest/tutorial.html)
#
# * Последовательно обучите несколько моделей, используя при этом разные [функции потерь ](https://segmentation-models.readthedocs.io/en/latest/api.html#losses)
#
# > [Реализация всех имеющихся в модуле функций потерь на GIT разработчиков](https://github.com/qubvel/segmentation_models/blob/master/segmentation_models/losses.py)
#
# * При обучении используйте несколько метрик [метрик](https://segmentation-models.readthedocs.io/en/latest/api.html#metrics), определив их в массиве.
#
#
#
# Пример:
#
# ```
# metrics = ['accuracy', sm.metrics.iou_score]
#
# model.compile('Adam', loss=sm.losses.categorical_focal_jaccard_loss, metrics=metrics)
# ```
# > [Реализация всех имеющихся в модуле метрик на GIT разработчиков](https://github.com/qubvel/segmentation_models/blob/master/segmentation_models/metrics.py)

# %%
# Ваш код

# %% [markdown]
# ## Этап 4. Визуализация процесса обучения. Оценка точности

# %%
# Ваш код

# %% [markdown]
# ### 4.1. Визуализация процесса обучения

# %%
# Ваш код

# %% [markdown]
# ### 4.2. Оценка оценка точности по валидационной выборке

# %%
# Ваш код

# %% [markdown]
# ### 4.3. Визуализация предсказаний и сравнение их с оригинальными масками

# %%
# Ваш код

# %% [markdown]
# # Задание №2. Создание и обучение модели семантической сегментации для классификации спутниковых снимков

# %% [markdown]
# ## Пример создания модели с Unet-подобной архитектурой

# %%
from tensorflow.keras import Model, Input
from keras.layers import Conv2D, MaxPooling2D, concatenate, UpSampling2D, Dropout, Cropping2D, Softmax, Conv2DTranspose
from keras.preprocessing import image
from keras.utils.vis_utils import plot_model

# %%
def mini_u_net(image_shape, num_of_classes):

  input_image = Input(image_shape)

  # Encoder

  conv1_1 = Conv2D(filters = 32, kernel_size = (3, 3), padding = 'same', activation = 'relu', name = 'conv1_1')(input_image)
  conv1_2 = Conv2D(filters = 32, kernel_size = (3, 3), padding = 'same', activation = 'relu', name = 'conv1_2')(conv1_1)

  pool_1 = MaxPooling2D(name = 'pool_1')(conv1_2)

  conv2_1 = Conv2D(filters = 64, kernel_size = (3, 3), padding = 'same', activation = 'relu', name = 'conv2_1')(pool_1)
  conv2_2 = Conv2D(filters = 64, kernel_size = (3, 3), padding = 'same', activation = 'relu', name = 'conv2_2')(conv2_1)

  pool_2 = MaxPooling2D(name = 'pool_2')(conv2_2)

  conv3_1 = Conv2D(filters = 128, kernel_size = (3, 3), padding = 'same', activation = 'relu', name = 'conv3_1')(pool_2)
  conv3_2 = Conv2D(filters = 128, kernel_size = (3, 3), padding = 'same', activation = 'relu', name = 'conv3_2')(conv3_1)

  pool_3 = MaxPooling2D(name = 'pool_3')(conv3_2)

  conv4_1 = Conv2D(filters = 256, kernel_size = (3, 3), padding = 'same', activation = 'relu', name = 'conv4_1')(pool_3)
  conv4_2 = Conv2D(filters = 256, kernel_size = (3, 3), padding = 'same', activation = 'relu', name = 'conv4_2')(conv4_1)



  # Decoder

  upconv5_1 = UpSampling2D(name = 'upconv5_1')(conv4_2)
  upconv5_2 = Conv2D(filters = 128, kernel_size = (2, 2), activation = 'relu', padding = 'same', name = 'upconv5_2')(upconv5_1)
  concat_5 = concatenate([upconv5_2, conv3_2], axis = 3, name = 'concat_5') # Split Connections

  conv5_1 = Conv2D(filters = 128, kernel_size = (3, 3), padding = 'same', activation = 'relu', name = 'conv5_1')(concat_5)
  conv5_2 = Conv2D(filters = 128, kernel_size = (3, 3), padding = 'same', activation = 'relu', name = 'conv5_2')(conv5_1)


  upconv6_1 = UpSampling2D(name = 'upconv6_1')(conv5_2)
  upconv6_2 = Conv2D(filters = 64, kernel_size = (2, 2), activation = 'relu', padding = 'same', name = 'upconv6_2')(upconv6_1)
  concat_6 = concatenate([upconv6_2, conv2_2], axis = 3, name = 'concat_6') # Split Connections

  conv6_1 = Conv2D(filters = 64, kernel_size = (3, 3), padding = 'same', activation = 'relu', name = 'conv6_1')(concat_6)
  conv6_2 = Conv2D(filters = 64, kernel_size = (3, 3), padding = 'same', activation = 'relu', name = 'conv6_2')(conv6_1)

  upconv7_1 = UpSampling2D(name = 'upconv7_1')(conv6_2)
  upconv7_2 = Conv2D(filters = 32, kernel_size = (2, 2), activation = 'relu', padding = 'same', name = 'upconv7_2')(upconv7_1)
  concat_7 = concatenate([upconv7_2, conv1_2], axis = 3, name = 'concat_7') # Split Connections

  conv7_1 = Conv2D(filters = 32, kernel_size = (3, 3), padding = 'same', activation = 'relu', name = 'conv7_1')(concat_7)
  conv7_2 = Conv2D(filters = 32, kernel_size = (3, 3), padding = 'same', activation = 'relu', name = 'conv7_2')(conv7_1)

  conv8 = Conv2D(filters = num_of_classes, kernel_size = (1, 1), activation = 'softmax', name = 'conv8')(conv7_2)

  model = Model(inputs = input_image, outputs = conv8, name = 'model')

  return model

# %%
unet_model = mini_u_net(image_shape = [256, 256, 3], num_of_classes = 6)

# %% [markdown]
# ### Описание и визуализация архитектуры созданной модели

# %%
unet_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv1_1 (Conv2D)               (None, 256, 256, 32  896         ['input_1[0][0]']
#                                 )
#
#  conv1_2 (Conv2D)               (None, 256, 256, 32  9248        ['conv1_1[0][0]']
#                                 )
#
#  pool_1 (MaxPooling2D)          (None, 128, 128, 32  0           ['conv1_2[0][0]']
#                                 )
#
#  conv2_1 (Conv2D)               (None, 128, 128, 64  18496       ['pool_1[0][0]']
#                                 )
#
#  conv2_2 (Conv2D)               (None, 128, 128, 64  36928       ['conv2_1[0][0]']
#                                 )
#
#  pool_2 (MaxPooling2D)          (None, 64, 64, 64)   0           ['conv2_2[0][0]']
#
#  conv3_1 (Conv2D)               (None, 64, 64, 128)  73856       ['pool_2[0][0]']
#
#  conv3_2 (Conv2D)               (None, 64, 64, 128)  147584      ['conv3_1[0][0]']
#
#  pool_3 (MaxPooling2D)          (None, 32, 32, 128)  0           ['conv3_2[0][0]']
#
#  conv4_1 (Conv2D)               (None, 32, 32, 256)  295168      ['pool_3[0][0]']
#
#  conv4_2 (Conv2D)               (None, 32, 32, 256)  590080      ['conv4_1[0][0]']
#
#  upconv5_1 (UpSampling2D)       (None, 64, 64, 256)  0           ['conv4_2[0][0]']
#
#  upconv5_2 (Conv2D)             (None, 64, 64, 128)  131200      ['upconv5_1[0][0]']
#
#  concat_5 (Concatenate)         (None, 64, 64, 256)  0           ['upconv5_2[0][0]',
#                                                                   'conv3_2[0][0]']
#
#  conv5_1 (Conv2D)               (None, 64, 64, 128)  295040      ['concat_5[0][0]']
#
#  conv5_2 (Conv2D)               (None, 64, 64, 128)  147584      ['conv5_1[0][0]']
#
#  upconv6_1 (UpSampling2D)       (None, 128, 128, 12  0           ['conv5_2[0][0]']
#                                 8)
#
#  upconv6_2 (Conv2D)             (None, 128, 128, 64  32832       ['upconv6_1[0][0]']
#                                 )
#
#  concat_6 (Concatenate)         (None, 128, 128, 12  0           ['upconv6_2[0][0]',
#                                 8)                                'conv2_2[0][0]']
#
#  conv6_1 (Conv2D)               (None, 128, 128, 64  73792       ['concat_6[0][0]']
#                                 )
#
#  conv6_2 (Conv2D)               (None, 128, 128, 64  36928       ['conv6_1[0][0]']
#                                 )
#
#  upconv7_1 (UpSampling2D)       (None, 256, 256, 64  0           ['conv6_2[0][0]']
#                                 )
#
#  upconv7_2 (Conv2D)             (None, 256, 256, 32  8224        ['upconv7_1[0][0]']
#                                 )
#
#  concat_7 (Concatenate)         (None, 256, 256, 64  0           ['upconv7_2[0][0]',
#                                 )                                 'conv1_2[0][0]']
#
#  conv7_1 (Conv2D)               (None, 256, 256, 32  18464       ['concat_7[0][0]']
#                                 )
#
#  conv7_2 (Conv2D)               (None, 256, 256, 32  9248        ['conv7_1[0][0]']
#                                 )
#
#  conv8 (Conv2D)                 (None, 256, 256, 6)  198         ['conv7_2[0][0]']
#
# ==================================================================================================
# Total params: 1,925,766
# Trainable params: 1,925,766
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
unet_model.get_config()
# Out:
# {'name': 'model',
#  'trainable': True,
#  'layers': [{'class_name': 'InputLayer',
#    'config': {'batch_input_shape': (None, 256, 256, 3),
#     'dtype': 'float32',
#     'sparse': False,
#     'ragged': False,
#     'name': 'input_1'},
#    'name': 'input_1',
#    'inbound_nodes': []},
#   {'class_name': 'Conv2D',
#    'config': {'name': 'conv1_1',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 32,
#     'kernel_size': (3, 3),
#     'strides': (1, 1),
#     'padding': 'same',
#     'data_format': 'channels_last',
#     'dilation_rate': (1, 1),
#     'groups': 1,
#     'activation': 'relu',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'GlorotUniform',
#      'config': {'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'name': 'conv1_1',
#    'inbound_nodes': [[['input_1', 0, 0, {}]]]},
#   {'class_name': 'Conv2D',
#    'config': {'name': 'conv1_2',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 32,
#     'kernel_size': (3, 3),
#     'strides': (1, 1),
#     'padding': 'same',
#     'data_format': 'channels_last',
#     'dilation_rate': (1, 1),
#     'groups': 1,
#     'activation': 'relu',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'GlorotUniform',
#      'config': {'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'name': 'conv1_2',
#    'inbound_nodes': [[['conv1_1', 0, 0, {}]]]},
#   {'class_name': 'MaxPooling2D',
#    'config': {'name': 'pool_1',
#     'trainable': True,
#     'dtype': 'float32',
#     'pool_size': (2, 2),
#     'padding': 'valid',
#     'strides': (2, 2),
#     'data_format': 'channels_last'},
#    'name': 'pool_1',
#    'inbound_nodes': [[['conv1_2', 0, 0, {}]]]},
#   {'class_name': 'Conv2D',
#    'config': {'name': 'conv2_1',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 64,
#     'kernel_size': (3, 3),
#     'strides': (1, 1),
#     'padding': 'same',
#     'data_format': 'channels_last',
#     'dilation_rate': (1, 1),
#     'groups': 1,
#     'activation': 'relu',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'GlorotUniform',
#      'config': {'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'name': 'conv2_1',
#    'inbound_nodes': [[['pool_1', 0, 0, {}]]]},
#   {'class_name': 'Conv2D',
#    'config': {'name': 'conv2_2',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 64,
#     'kernel_size': (3, 3),
#     'strides': (1, 1),
#     'padding': 'same',
#     'data_format': 'channels_last',
#     'dilation_rate': (1, 1),
#     'groups': 1,
#     'activation': 'relu',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'GlorotUniform',
#      'config': {'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'name': 'conv2_2',
#    'inbound_nodes': [[['conv2_1', 0, 0, {}]]]},
#   {'class_name': 'MaxPooling2D',
#    'config': {'name': 'pool_2',
#     'trainable': True,
#     'dtype': 'float32',
#     'pool_size': (2, 2),
#     'padding': 'valid',
#     'strides': (2, 2),
#     'data_format': 'channels_last'},
#    'name': 'pool_2',
#    'inbound_nodes': [[['conv2_2', 0, 0, {}]]]},
#   {'class_name': 'Conv2D',
#    'config': {'name': 'conv3_1',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 128,
#     'kernel_size': (3, 3),
#     'strides': (1, 1),
#     'padding': 'same',
#     'data_format': 'channels_last',
#     'dilation_rate': (1, 1),
#     'groups': 1,
#     'activation': 'relu',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'GlorotUniform',
#      'config': {'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'name': 'conv3_1',
#    'inbound_nodes': [[['pool_2', 0, 0, {}]]]},
#   {'class_name': 'Conv2D',
#    'config': {'name': 'conv3_2',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 128,
#     'kernel_size': (3, 3),
#     'strides': (1, 1),
#     'padding': 'same',
#     'data_format': 'channels_last',
#     'dilation_rate': (1, 1),
#     'groups': 1,
#     'activation': 'relu',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'GlorotUniform',
#      'config': {'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'name': 'conv3_2',
#    'inbound_nodes': [[['conv3_1', 0, 0, {}]]]},
#   {'class_name': 'MaxPooling2D',
#    'config': {'name': 'pool_3',
#     'trainable': True,
#     'dtype': 'float32',
#     'pool_size': (2, 2),
#     'padding': 'valid',
#     'strides': (2, 2),
#     'data_format': 'channels_last'},
#    'name': 'pool_3',
#    'inbound_nodes': [[['conv3_2', 0, 0, {}]]]},
#   {'class_name': 'Conv2D',
#    'config': {'name': 'conv4_1',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 256,
#     'kernel_size': (3, 3),
#     'strides': (1, 1),
#     'padding': 'same',
#     'data_format': 'channels_last',
#     'dilation_rate': (1, 1),
#     'groups': 1,
#     'activation': 'relu',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'GlorotUniform',
#      'config': {'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'name': 'conv4_1',
#    'inbound_nodes': [[['pool_3', 0, 0, {}]]]},
#   {'class_name': 'Conv2D',
#    'config': {'name': 'conv4_2',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 256,
#     'kernel_size': (3, 3),
#     'strides': (1, 1),
#     'padding': 'same',
#     'data_format': 'channels_last',
#     'dilation_rate': (1, 1),
#     'groups': 1,
#     'activation': 'relu',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'GlorotUniform',
#      'config': {'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'name': 'conv4_2',
#    'inbound_nodes': [[['conv4_1', 0, 0, {}]]]},
#   {'class_name': 'UpSampling2D',
#    'config': {'name': 'upconv5_1',
#     'trainable': True,
#     'dtype': 'float32',
#     'size': (2, 2),
#     'data_format': 'channels_last',
#     'interpolation': 'nearest'},
#    'name': 'upconv5_1',
#    'inbound_nodes': [[['conv4_2', 0, 0, {}]]]},
#   {'class_name': 'Conv2D',
#    'config': {'name': 'upconv5_2',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 128,
#     'kernel_size': (2, 2),
#     'strides': (1, 1),
#     'padding': 'same',
#     'data_format': 'channels_last',
#     'dilation_rate': (1, 1),
#     'groups': 1,
#     'activation': 'relu',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'GlorotUniform',
#      'config': {'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'name': 'upconv5_2',
#    'inbound_nodes': [[['upconv5_1', 0, 0, {}]]]},
#   {'class_name': 'Concatenate',
#    'config': {'name': 'concat_5',
#     'trainable': True,
#     'dtype': 'float32',
#     'axis': 3},
#    'name': 'concat_5',
#    'inbound_nodes': [[['upconv5_2', 0, 0, {}], ['conv3_2', 0, 0, {}]]]},
#   {'class_name': 'Conv2D',
#    'config': {'name': 'conv5_1',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 128,
#     'kernel_size': (3, 3),
#     'strides': (1, 1),
#     'padding': 'same',
#     'data_format': 'channels_last',
#     'dilation_rate': (1, 1),
#     'groups': 1,
#     'activation': 'relu',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'GlorotUniform',
#      'config': {'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'name': 'conv5_1',
#    'inbound_nodes': [[['concat_5', 0, 0, {}]]]},
#   {'class_name': 'Conv2D',
#    'config': {'name': 'conv5_2',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 128,
#     'kernel_size': (3, 3),
#     'strides': (1, 1),
#     'padding': 'same',
#     'data_format': 'channels_last',
#     'dilation_rate': (1, 1),
#     'groups': 1,
#     'activation': 'relu',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'GlorotUniform',
#      'config': {'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'name': 'conv5_2',
#    'inbound_nodes': [[['conv5_1', 0, 0, {}]]]},
#   {'class_name': 'UpSampling2D',
#    'config': {'name': 'upconv6_1',
#     'trainable': True,
#     'dtype': 'float32',
#     'size': (2, 2),
#     'data_format': 'channels_last',
#     'interpolation': 'nearest'},
#    'name': 'upconv6_1',
#    'inbound_nodes': [[['conv5_2', 0, 0, {}]]]},
#   {'class_name': 'Conv2D',
#    'config': {'name': 'upconv6_2',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 64,
#     'kernel_size': (2, 2),
#     'strides': (1, 1),
#     'padding': 'same',
#     'data_format': 'channels_last',
#     'dilation_rate': (1, 1),
#     'groups': 1,
#     'activation': 'relu',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'GlorotUniform',
#      'config': {'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'name': 'upconv6_2',
#    'inbound_nodes': [[['upconv6_1', 0, 0, {}]]]},
#   {'class_name': 'Concatenate',
#    'config': {'name': 'concat_6',
#     'trainable': True,
#     'dtype': 'float32',
#     'axis': 3},
#    'name': 'concat_6',
#    'inbound_nodes': [[['upconv6_2', 0, 0, {}], ['conv2_2', 0, 0, {}]]]},
#   {'class_name': 'Conv2D',
#    'config': {'name': 'conv6_1',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 64,
#     'kernel_size': (3, 3),
#     'strides': (1, 1),
#     'padding': 'same',
#     'data_format': 'channels_last',
#     'dilation_rate': (1, 1),
#     'groups': 1,
#     'activation': 'relu',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'GlorotUniform',
#      'config': {'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'name': 'conv6_1',
#    'inbound_nodes': [[['concat_6', 0, 0, {}]]]},
#   {'class_name': 'Conv2D',
#    'config': {'name': 'conv6_2',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 64,
#     'kernel_size': (3, 3),
#     'strides': (1, 1),
#     'padding': 'same',
#     'data_format': 'channels_last',
#     'dilation_rate': (1, 1),
#     'groups': 1,
#     'activation': 'relu',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'GlorotUniform',
#      'config': {'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'name': 'conv6_2',
#    'inbound_nodes': [[['conv6_1', 0, 0, {}]]]},
#   {'class_name': 'UpSampling2D',
#    'config': {'name': 'upconv7_1',
#     'trainable': True,
#     'dtype': 'float32',
#     'size': (2, 2),
#     'data_format': 'channels_last',
#     'interpolation': 'nearest'},
#    'name': 'upconv7_1',
#    'inbound_nodes': [[['conv6_2', 0, 0, {}]]]},
#   {'class_name': 'Conv2D',
#    'config': {'name': 'upconv7_2',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 32,
#     'kernel_size': (2, 2),
#     'strides': (1, 1),
#     'padding': 'same',
#     'data_format': 'channels_last',
#     'dilation_rate': (1, 1),
#     'groups': 1,
#     'activation': 'relu',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'GlorotUniform',
#      'config': {'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'name': 'upconv7_2',
#    'inbound_nodes': [[['upconv7_1', 0, 0, {}]]]},
#   {'class_name': 'Concatenate',
#    'config': {'name': 'concat_7',
#     'trainable': True,
#     'dtype': 'float32',
#     'axis': 3},
#    'name': 'concat_7',
#    'inbound_nodes': [[['upconv7_2', 0, 0, {}], ['conv1_2', 0, 0, {}]]]},
#   {'class_name': 'Conv2D',
#    'config': {'name': 'conv7_1',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 32,
#     'kernel_size': (3, 3),
#     'strides': (1, 1),
#     'padding': 'same',
#     'data_format': 'channels_last',
#     'dilation_rate': (1, 1),
#     'groups': 1,
#     'activation': 'relu',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'GlorotUniform',
#      'config': {'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'name': 'conv7_1',
#    'inbound_nodes': [[['concat_7', 0, 0, {}]]]},
#   {'class_name': 'Conv2D',
#    'config': {'name': 'conv7_2',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 32,
#     'kernel_size': (3, 3),
#     'strides': (1, 1),
#     'padding': 'same',
#     'data_format': 'channels_last',
#     'dilation_rate': (1, 1),
#     'groups': 1,
#     'activation': 'relu',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'GlorotUniform',
#      'config': {'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'name': 'conv7_2',
#    'inbound_nodes': [[['conv7_1', 0, 0, {}]]]},
#   {'class_name': 'Conv2D',
#    'config': {'name': 'conv8',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 6,
#     'kernel_size': (1, 1),
#     'strides': (1, 1),
#     'padding': 'valid',
#     'data_format': 'channels_last',
#     'dilation_rate': (1, 1),
#     'groups': 1,
#     'activation': 'softmax',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'GlorotUniform',
#      'config': {'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'name': 'conv8',
#    'inbound_nodes': [[['conv7_2', 0, 0, {}]]]}],
#  'input_layers': [['input_1', 0, 0]],
#  'output_layers': [['conv8', 0, 0]]}

# %% [markdown]
# Для визуализации архитектуры модели используется следующий код:
#
# ```
# plot_model(
# unet_model, to_file='model.png', show_shapes=False, show_dtype=False,
# show_layer_names=True, rankdir='TB', expand_nested=False, dpi=96
# )
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 2.1. Создайте модель со следующей архитектурой:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
model_2.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d_29 (Conv2D)             (None, 256, 256, 16  448         ['input_4[0][0]']
#                                 )
#
#  dropout_14 (Dropout)           (None, 256, 256, 16  0           ['conv2d_29[0][0]']
#                                 )
#
#  conv2d_30 (Conv2D)             (None, 256, 256, 16  2320        ['dropout_14[0][0]']
#                                 )
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 128, 128, 16  0          ['conv2d_30[0][0]']
#                                 )
#
#  conv2d_31 (Conv2D)             (None, 128, 128, 32  4640        ['max_pooling2d_8[0][0]']
#                                 )
#
#  dropout_15 (Dropout)           (None, 128, 128, 32  0           ['conv2d_31[0][0]']
#                                 )
#
#  conv2d_32 (Conv2D)             (None, 128, 128, 32  9248        ['dropout_15[0][0]']
#                                 )
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 64, 64, 32)  0           ['conv2d_32[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 64, 64, 64)   18496       ['max_pooling2d_9[0][0]']
#
#  dropout_16 (Dropout)           (None, 64, 64, 64)   0           ['conv2d_33[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 64, 64, 64)   36928       ['dropout_16[0][0]']
#
#  max_pooling2d_10 (MaxPooling2D  (None, 32, 32, 64)  0           ['conv2d_34[0][0]']
#  )
#
#  conv2d_35 (Conv2D)             (None, 32, 32, 128)  73856       ['max_pooling2d_10[0][0]']
#
#  dropout_17 (Dropout)           (None, 32, 32, 128)  0           ['conv2d_35[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 32, 32, 128)  147584      ['dropout_17[0][0]']
#
#  max_pooling2d_11 (MaxPooling2D  (None, 16, 16, 128)  0          ['conv2d_36[0][0]']
#  )
#
#  conv2d_37 (Conv2D)             (None, 16, 16, 256)  295168      ['max_pooling2d_11[0][0]']
#
#  dropout_18 (Dropout)           (None, 16, 16, 256)  0           ['conv2d_37[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 16, 16, 256)  590080      ['dropout_18[0][0]']
#
#  conv2d_transpose_4 (Conv2DTran  (None, 32, 32, 128)  131200     ['conv2d_38[0][0]']
#  spose)
#
#  concatenate_4 (Concatenate)    (None, 32, 32, 256)  0           ['conv2d_transpose_4[0][0]',
#                                                                   'conv2d_36[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 32, 32, 128)  295040      ['concatenate_4[0][0]']
#
#  dropout_19 (Dropout)           (None, 32, 32, 128)  0           ['conv2d_39[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 32, 32, 128)  147584      ['dropout_19[0][0]']
#
#  conv2d_transpose_5 (Conv2DTran  (None, 64, 64, 64)  32832       ['conv2d_40[0][0]']
#  spose)
#
#  concatenate_5 (Concatenate)    (None, 64, 64, 128)  0           ['conv2d_transpose_5[0][0]',
#                                                                   'conv2d_34[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 64, 64, 64)   73792       ['concatenate_5[0][0]']
#
#  dropout_20 (Dropout)           (None, 64, 64, 64)   0           ['conv2d_41[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 64, 64, 64)   36928       ['dropout_20[0][0]']
#
#  conv2d_transpose_6 (Conv2DTran  (None, 128, 128, 32  8224       ['conv2d_42[0][0]']
#  spose)                         )
#
#  concatenate_6 (Concatenate)    (None, 128, 128, 64  0           ['conv2d_transpose_6[0][0]',
#                                 )                                 'conv2d_32[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 128, 128, 32  18464       ['concatenate_6[0][0]']
#                                 )
#
#  dropout_21 (Dropout)           (None, 128, 128, 32  0           ['conv2d_43[0][0]']
#                                 )
#
#  conv2d_44 (Conv2D)             (None, 128, 128, 32  9248        ['dropout_21[0][0]']
#                                 )
#
#  conv2d_transpose_7 (Conv2DTran  (None, 256, 256, 16  2064       ['conv2d_44[0][0]']
#  spose)                         )
#
#  concatenate_7 (Concatenate)    (None, 256, 256, 32  0           ['conv2d_transpose_7[0][0]',
#                                 )                                 'conv2d_30[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 256, 256, 16  4624        ['concatenate_7[0][0]']
#                                 )
#
#  dropout_22 (Dropout)           (None, 256, 256, 16  0           ['conv2d_45[0][0]']
#                                 )
#
#  conv2d_46 (Conv2D)             (None, 256, 256, 16  2320        ['dropout_22[0][0]']
#                                 )
#
#  conv2d_47 (Conv2D)             (None, 256, 256, 6)  102         ['conv2d_46[0][0]']
#
# ==================================================================================================
# Total params: 1,941,190
# Trainable params: 1,941,190
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model_2.get_config()
# Out:
# {'name': 'model_1',
#  'trainable': True,
#  'layers': [{'class_name': 'InputLayer',
#    'config': {'batch_input_shape': (None, 256, 256, 3),
#     'dtype': 'float32',
#     'sparse': False,
#     'ragged': False,
#     'name': 'input_4'},
#    'name': 'input_4',
#    'inbound_nodes': []},
#   {'class_name': 'Conv2D',
#    'config': {'name': 'conv2d_29',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 16,
#     'kernel_size': (3, 3),
#     'strides': (1, 1),
#     'padding': 'same',
#     'data_format': 'channels_last',
#     'dilation_rate': (1, 1),
#     'groups': 1,
#     'activation': 'relu',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'HeNormal', 'config': {'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'name': 'conv2d_29',
#    'inbound_nodes': [[['input_4', 0, 0, {}]]]},
#   {'class_name': 'Dropout',
#    'config': {'name': 'dropout_14',
#     'trainable': True,
#     'dtype': 'float32',
#     'rate': 0.2,
#     'noise_shape': None,
#     'seed': None},
#    'name': 'dropout_14',
#    'inbound_nodes': [[['conv2d_29', 0, 0, {}]]]},
#   {'class_name': 'Conv2D',
#    'config': {'name': 'conv2d_30',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 16,
#     'kernel_size': (3, 3),
#     'strides': (1, 1),
#     'padding': 'same',
#     'data_format': 'channels_last',
#     'dilation_rate': (1, 1),
#     'groups': 1,
#     'activation': 'relu',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'HeNormal', 'config': {'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'name': 'conv2d_30',
#    'inbound_nodes': [[['dropout_14', 0, 0, {}]]]},
#   {'class_name': 'MaxPooling2D',
#    'config': {'name': 'max_pooling2d_8',
#     'trainable': True,
#     'dtype': 'float32',
#     'pool_size': (2, 2),
#     'padding': 'valid',
#     'strides': (2, 2),
#     'data_format': 'channels_last'},
#    'name': 'max_pooling2d_8',
#    'inbound_nodes': [[['conv2d_30', 0, 0, {}]]]},
#   {'class_name': 'Conv2D',
#    'config': {'name': 'conv2d_31',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 32,
#     'kernel_size': (3, 3),
#     'strides': (1, 1),
#     'padding': 'same',
#     'data_format': 'channels_last',
#     'dilation_rate': (1, 1),
#     'groups': 1,
#     'activation': 'relu',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'HeNormal', 'config': {'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'name': 'conv2d_31',
#    'inbound_nodes': [[['max_pooling2d_8', 0, 0, {}]]]},
#   {'class_name': 'Dropout',
#    'config': {'name': 'dropout_15',
#     'trainable': True,
#     'dtype': 'float32',
#     'rate': 0.2,
#     'noise_shape': None,
#     'seed': None},
#    'name': 'dropout_15',
#    'inbound_nodes': [[['conv2d_31', 0, 0, {}]]]},
#   {'class_name': 'Conv2D',
#    'config': {'name': 'conv2d_32',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 32,
#     'kernel_size': (3, 3),
#     'strides': (1, 1),
#     'padding': 'same',
#     'data_format': 'channels_last',
#     'dilation_rate': (1, 1),
#     'groups': 1,
#     'activation': 'relu',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'HeNormal', 'config': {'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'name': 'conv2d_32',
#    'inbound_nodes': [[['dropout_15', 0, 0, {}]]]},
#   {'class_name': 'MaxPooling2D',
#    'config': {'name': 'max_pooling2d_9',
#     'trainable': True,
#     'dtype': 'float32',
#     'pool_size': (2, 2),
#     'padding': 'valid',
#     'strides': (2, 2),
#     'data_format': 'channels_last'},
#    'name': 'max_pooling2d_9',
#    'inbound_nodes': [[['conv2d_32', 0, 0, {}]]]},
#   {'class_name': 'Conv2D',
#    'config': {'name': 'conv2d_33',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 64,
#     'kernel_size': (3, 3),
#     'strides': (1, 1),
#     'padding': 'same',
#     'data_format': 'channels_last',
#     'dilation_rate': (1, 1),
#     'groups': 1,
#     'activation': 'relu',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'HeNormal', 'config': {'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'name': 'conv2d_33',
#    'inbound_nodes': [[['max_pooling2d_9', 0, 0, {}]]]},
#   {'class_name': 'Dropout',
#    'config': {'name': 'dropout_16',
#     'trainable': True,
#     'dtype': 'float32',
#     'rate': 0.2,
#     'noise_shape': None,
#     'seed': None},
#    'name': 'dropout_16',
#    'inbound_nodes': [[['conv2d_33', 0, 0, {}]]]},
#   {'class_name': 'Conv2D',
#    'config': {'name': 'conv2d_34',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 64,
#     'kernel_size': (3, 3),
#     'strides': (1, 1),
#     'padding': 'same',
#     'data_format': 'channels_last',
#     'dilation_rate': (1, 1),
#     'groups': 1,
#     'activation': 'relu',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'HeNormal', 'config': {'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'name': 'conv2d_34',
#    'inbound_nodes': [[['dropout_16', 0, 0, {}]]]},
#   {'class_name': 'MaxPooling2D',
#    'config': {'name': 'max_pooling2d_10',
#     'trainable': True,
#     'dtype': 'float32',
#     'pool_size': (2, 2),
#     'padding': 'valid',
#     'strides': (2, 2),
#     'data_format': 'channels_last'},
#    'name': 'max_pooling2d_10',
#    'inbound_nodes': [[['conv2d_34', 0, 0, {}]]]},
#   {'class_name': 'Conv2D',
#    'config': {'name': 'conv2d_35',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 128,
#     'kernel_size': (3, 3),
#     'strides': (1, 1),
#     'padding': 'same',
#     'data_format': 'channels_last',
#     'dilation_rate': (1, 1),
#     'groups': 1,
#     'activation': 'relu',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'HeNormal', 'config': {'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'name': 'conv2d_35',
#    'inbound_nodes': [[['max_pooling2d_10', 0, 0, {}]]]},
#   {'class_name': 'Dropout',
#    'config': {'name': 'dropout_17',
#     'trainable': True,
#     'dtype': 'float32',
#     'rate': 0.2,
#     'noise_shape': None,
#     'seed': None},
#    'name': 'dropout_17',
#    'inbound_nodes': [[['conv2d_35', 0, 0, {}]]]},
#   {'class_name': 'Conv2D',
#    'config': {'name': 'conv2d_36',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 128,
#     'kernel_size': (3, 3),
#     'strides': (1, 1),
#     'padding': 'same',
#     'data_format': 'channels_last',
#     'dilation_rate': (1, 1),
#     'groups': 1,
#     'activation': 'relu',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'HeNormal', 'config': {'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'name': 'conv2d_36',
#    'inbound_nodes': [[['dropout_17', 0, 0, {}]]]},
#   {'class_name': 'MaxPooling2D',
#    'config': {'name': 'max_pooling2d_11',
#     'trainable': True,
#     'dtype': 'float32',
#     'pool_size': (2, 2),
#     'padding': 'valid',
#     'strides': (2, 2),
#     'data_format': 'channels_last'},
#    'name': 'max_pooling2d_11',
#    'inbound_nodes': [[['conv2d_36', 0, 0, {}]]]},
#   {'class_name': 'Conv2D',
#    'config': {'name': 'conv2d_37',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 256,
#     'kernel_size': (3, 3),
#     'strides': (1, 1),
#     'padding': 'same',
#     'data_format': 'channels_last',
#     'dilation_rate': (1, 1),
#     'groups': 1,
#     'activation': 'relu',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'HeNormal', 'config': {'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'name': 'conv2d_37',
#    'inbound_nodes': [[['max_pooling2d_11', 0, 0, {}]]]},
#   {'class_name': 'Dropout',
#    'config': {'name': 'dropout_18',
#     'trainable': True,
#     'dtype': 'float32',
#     'rate': 0.3,
#     'noise_shape': None,
#     'seed': None},
#    'name': 'dropout_18',
#    'inbound_nodes': [[['conv2d_37', 0, 0, {}]]]},
#   {'class_name': 'Conv2D',
#    'config': {'name': 'conv2d_38',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 256,
#     'kernel_size': (3, 3),
#     'strides': (1, 1),
#     'padding': 'same',
#     'data_format': 'channels_last',
#     'dilation_rate': (1, 1),
#     'groups': 1,
#     'activation': 'relu',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'HeNormal', 'config': {'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'name': 'conv2d_38',
#    'inbound_nodes': [[['dropout_18', 0, 0, {}]]]},
#   {'class_name': 'Conv2DTranspose',
#    'config': {'name': 'conv2d_transpose_4',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 128,
#     'kernel_size': (2, 2),
#     'strides': (2, 2),
#     'padding': 'same',
#     'data_format': 'channels_last',
#     'dilation_rate': (1, 1),
#     'groups': 1,
#     'activation': 'linear',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'GlorotUniform',
#      'config': {'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None,
#     'output_padding': None},
#    'name': 'conv2d_transpose_4',
#    'inbound_nodes': [[['conv2d_38', 0, 0, {}]]]},
#   {'class_name': 'Concatenate',
#    'config': {'name': 'concatenate_4',
#     'trainable': True,
#     'dtype': 'float32',
#     'axis': -1},
#    'name': 'concatenate_4',
#    'inbound_nodes': [[['conv2d_transpose_4', 0, 0, {}],
#      ['conv2d_36', 0, 0, {}]]]},
#   {'class_name': 'Conv2D',
#    'config': {'name': 'conv2d_39',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 128,
#     'kernel_size': (3, 3),
#     'strides': (1, 1),
#     'padding': 'same',
#     'data_format': 'channels_last',
#     'dilation_rate': (1, 1),
#     'groups': 1,
#     'activation': 'relu',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'HeNormal', 'config': {'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'name': 'conv2d_39',
#    'inbound_nodes': [[['concatenate_4', 0, 0, {}]]]},
#   {'class_name': 'Dropout',
#    'config': {'name': 'dropout_19',
#     'trainable': True,
#     'dtype': 'float32',
#     'rate': 0.2,
#     'noise_shape': None,
#     'seed': None},
#    'name': 'dropout_19',
#    'inbound_nodes': [[['conv2d_39', 0, 0, {}]]]},
#   {'class_name': 'Conv2D',
#    'config': {'name': 'conv2d_40',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 128,
#     'kernel_size': (3, 3),
#     'strides': (1, 1),
#     'padding': 'same',
#     'data_format': 'channels_last',
#     'dilation_rate': (1, 1),
#     'groups': 1,
#     'activation': 'relu',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'HeNormal', 'config': {'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'name': 'conv2d_40',
#    'inbound_nodes': [[['dropout_19', 0, 0, {}]]]},
#   {'class_name': 'Conv2DTranspose',
#    'config': {'name': 'conv2d_transpose_5',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 64,
#     'kernel_size': (2, 2),
#     'strides': (2, 2),
#     'padding': 'same',
#     'data_format': 'channels_last',
#     'dilation_rate': (1, 1),
#     'groups': 1,
#     'activation': 'linear',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'GlorotUniform',
#      'config': {'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None,
#     'output_padding': None},
#    'name': 'conv2d_transpose_5',
#    'inbound_nodes': [[['conv2d_40', 0, 0, {}]]]},
#   {'class_name': 'Concatenate',
#    'config': {'name': 'concatenate_5',
#     'trainable': True,
#     'dtype': 'float32',
#     'axis': -1},
#    'name': 'concatenate_5',
#    'inbound_nodes': [[['conv2d_transpose_5', 0, 0, {}],
#      ['conv2d_34', 0, 0, {}]]]},
#   {'class_name': 'Conv2D',
#    'config': {'name': 'conv2d_41',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 64,
#     'kernel_size': (3, 3),
#     'strides': (1, 1),
#     'padding': 'same',
#     'data_format': 'channels_last',
#     'dilation_rate': (1, 1),
#     'groups': 1,
#     'activation': 'relu',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'HeNormal', 'config': {'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'name': 'conv2d_41',
#    'inbound_nodes': [[['concatenate_5', 0, 0, {}]]]},
#   {'class_name': 'Dropout',
#    'config': {'name': 'dropout_20',
#     'trainable': True,
#     'dtype': 'float32',
#     'rate': 0.2,
#     'noise_shape': None,
#     'seed': None},
#    'name': 'dropout_20',
#    'inbound_nodes': [[['conv2d_41', 0, 0, {}]]]},
#   {'class_name': 'Conv2D',
#    'config': {'name': 'conv2d_42',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 64,
#     'kernel_size': (3, 3),
#     'strides': (1, 1),
#     'padding': 'same',
#     'data_format': 'channels_last',
#     'dilation_rate': (1, 1),
#     'groups': 1,
#     'activation': 'relu',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'HeNormal', 'config': {'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'name': 'conv2d_42',
#    'inbound_nodes': [[['dropout_20', 0, 0, {}]]]},
#   {'class_name': 'Conv2DTranspose',
#    'config': {'name': 'conv2d_transpose_6',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 32,
#     'kernel_size': (2, 2),
#     'strides': (2, 2),
#     'padding': 'same',
#     'data_format': 'channels_last',
#     'dilation_rate': (1, 1),
#     'groups': 1,
#     'activation': 'linear',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'GlorotUniform',
#      'config': {'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None,
#     'output_padding': None},
#    'name': 'conv2d_transpose_6',
#    'inbound_nodes': [[['conv2d_42', 0, 0, {}]]]},
#   {'class_name': 'Concatenate',
#    'config': {'name': 'concatenate_6',
#     'trainable': True,
#     'dtype': 'float32',
#     'axis': -1},
#    'name': 'concatenate_6',
#    'inbound_nodes': [[['conv2d_transpose_6', 0, 0, {}],
#      ['conv2d_32', 0, 0, {}]]]},
#   {'class_name': 'Conv2D',
#    'config': {'name': 'conv2d_43',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 32,
#     'kernel_size': (3, 3),
#     'strides': (1, 1),
#     'padding': 'same',
#     'data_format': 'channels_last',
#     'dilation_rate': (1, 1),
#     'groups': 1,
#     'activation': 'relu',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'HeNormal', 'config': {'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'name': 'conv2d_43',
#    'inbound_nodes': [[['concatenate_6', 0, 0, {}]]]},
#   {'class_name': 'Dropout',
#    'config': {'name': 'dropout_21',
#     'trainable': True,
#     'dtype': 'float32',
#     'rate': 0.2,
#     'noise_shape': None,
#     'seed': None},
#    'name': 'dropout_21',
#    'inbound_nodes': [[['conv2d_43', 0, 0, {}]]]},
#   {'class_name': 'Conv2D',
#    'config': {'name': 'conv2d_44',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 32,
#     'kernel_size': (3, 3),
#     'strides': (1, 1),
#     'padding': 'same',
#     'data_format': 'channels_last',
#     'dilation_rate': (1, 1),
#     'groups': 1,
#     'activation': 'relu',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'HeNormal', 'config': {'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'name': 'conv2d_44',
#    'inbound_nodes': [[['dropout_21', 0, 0, {}]]]},
#   {'class_name': 'Conv2DTranspose',
#    'config': {'name': 'conv2d_transpose_7',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 16,
#     'kernel_size': (2, 2),
#     'strides': (2, 2),
#     'padding': 'same',
#     'data_format': 'channels_last',
#     'dilation_rate': (1, 1),
#     'groups': 1,
#     'activation': 'linear',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'GlorotUniform',
#      'config': {'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None,
#     'output_padding': None},
#    'name': 'conv2d_transpose_7',
#    'inbound_nodes': [[['conv2d_44', 0, 0, {}]]]},
#   {'class_name': 'Concatenate',
#    'config': {'name': 'concatenate_7',
#     'trainable': True,
#     'dtype': 'float32',
#     'axis': 3},
#    'name': 'concatenate_7',
#    'inbound_nodes': [[['conv2d_transpose_7', 0, 0, {}],
#      ['conv2d_30', 0, 0, {}]]]},
#   {'class_name': 'Conv2D',
#    'config': {'name': 'conv2d_45',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 16,
#     'kernel_size': (3, 3),
#     'strides': (1, 1),
#     'padding': 'same',
#     'data_format': 'channels_last',
#     'dilation_rate': (1, 1),
#     'groups': 1,
#     'activation': 'relu',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'HeNormal', 'config': {'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'name': 'conv2d_45',
#    'inbound_nodes': [[['concatenate_7', 0, 0, {}]]]},
#   {'class_name': 'Dropout',
#    'config': {'name': 'dropout_22',
#     'trainable': True,
#     'dtype': 'float32',
#     'rate': 0.2,
#     'noise_shape': None,
#     'seed': None},
#    'name': 'dropout_22',
#    'inbound_nodes': [[['conv2d_45', 0, 0, {}]]]},
#   {'class_name': 'Conv2D',
#    'config': {'name': 'conv2d_46',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 16,
#     'kernel_size': (3, 3),
#     'strides': (1, 1),
#     'padding': 'same',
#     'data_format': 'channels_last',
#     'dilation_rate': (1, 1),
#     'groups': 1,
#     'activation': 'relu',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'HeNormal', 'config': {'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'name': 'conv2d_46',
#    'inbound_nodes': [[['dropout_22', 0, 0, {}]]]},
#   {'class_name': 'Conv2D',
#    'config': {'name': 'conv2d_47',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 6,
#     'kernel_size': (1, 1),
#     'strides': (1, 1),
#     'padding': 'valid',
#     'data_format': 'channels_last',
#     'dilation_rate': (1, 1),
#     'groups': 1,
#     'activation': 'softmax',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'GlorotUniform',
#      'config': {'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'name': 'conv2d_47',
#    'inbound_nodes': [[['conv2d_46', 0, 0, {}]]]}],
#  'input_layers': [['input_4', 0, 0]],
#  'output_layers': [['conv2d_47', 0, 0]]}

# %%
plot_model(
model_2, to_file='model.png', show_shapes=False, show_dtype=False,
show_layer_names=True, rankdir='TB', expand_nested=False, dpi=96
)

# %%
# Ваш код

# %% [markdown]
# ## 2.2. Обучите созданную модель для решения задачи семантической сегментации. В качестве функции потерь используйте ту, которая лучше всего показала себя в задании №1

# %% [markdown]
# ### 2.2.1. Загрузите три снимка, а также маски, соответствующие этим снимкам

# %%
# Ваш код

# %% [markdown]
# ### 2.2.2. Используя обученную модель, обработайте снимки по технологии, рассмотренной на практическом занятии (делим снимок на части, затем каждую часть обрабатываем нейросетью, а после соединяем все части для получения полноразмерной маски исходного снимка)

# %%
# Ваш код

# %% [markdown]
# ### 2.2.3. Загрузите наиболее удачную модель из предыдущего задания (Задания №1). Сравните её точность с моделью, обученной в этом задании:

# %%
# Ваш код

# %% [markdown]
# ### 2.2.4. Отобразите предсказанную маску для каждого из трех снимков, загруженных ранее, в следующем формате: (исходный снимок, эталонная маска, предсказанная маска по модели, обученной в этом задании, предсказанная маска по модели, обученной в первом задании.

# %%
# Ваш код

# %% [markdown]
# # Задание №3. Реализация готового решения для полноразмерной семантической сегментации спутникового снимка

# %% [markdown]
# ## Реализуйте готовый алгоритм, который принимает на вход полноразмерное изображение и маску (опционально). После чего на его основе формирует полноразмерную маску, предсказанную наиболее удачной моделью нейронной сети, обученной ранее в Задании №1 или Задании №2.

# %%
# Ваш код

# %% [markdown]
# - Сравните получившийся результат с эталонной маской

# %%
# Ваш код

# %% [markdown]
# - Реализуйте графический интерфейс с помощью Gradio. На вход подается только исходный растр - на выходе отображается сгенерированная маска. Также маска автоматически должна сохраняться в корневом каталоге.

# %%
# Ваш код
